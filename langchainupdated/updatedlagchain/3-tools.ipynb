# %% [markdown]
# ### Tools
# ##### models can requestv to call tools that perofm taska such as fecting data from database, searching the web , or running code. Tools are pairing of :
#
# ##### 1.A Schema , including the nmae of the tools a description , and/ or argumnet definitions (often a JSON schema)
#
# ##### 2.A Function or coroutine to execute

# %%
import os
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

from langchain.chat_models import init_chat_model

model = init_chat_model("groq:qwen/qwen3-32b")
response = model.invoke("why do parrots talk?")
response
# Out:
#   Cell In[3], line 2
#     os.environ("GROQ_API_KEY")=os.getenv("GROQ_API_KEY")
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
